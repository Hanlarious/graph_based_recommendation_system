# %% [markdown]
# # **Prelim**

# %%
# !pip install git+https://github.com/uma-pi1/kge.git
# Out:
# ...
#   Cloning https://github.com/uma-pi1/kge.git to /tmp/pip-req-build-wi98udob
#   Running command git clone -q https://github.com/uma-pi1/kge.git /tmp/pip-req-build-wi98udob
# ...
#      |████████████████████████████████| 14.8 MB 8.6 MB/s
# ...
#      |████████████████████████████████| 776.8 MB 17 kB/s
# ...
#      |████████████████████████████████| 690 kB 63.7 MB/s
# ...
#      |████████████████████████████████| 395 kB 72.2 MB/s
# ...
#      |████████████████████████████████| 492 kB 71.9 MB/s
# ...
#      |████████████████████████████████| 3.6 MB 54.1 MB/s
# ...
#      |████████████████████████████████| 18.3 MB 423 kB/s
# ...
#   Created wheel for libkge: filename=libkge-0.1-py3-none-any.whl size=25613 sha256=1d0dfb508855d11c0683fbe7c6039c564e3ab5fae4b959da704cc7f30954a0c8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xa9rs798/wheels/cd/4f/1d/3a5ecce4ba442b99aed1da672be3bacce27bb2f578668ec193
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
! rm -r graph_based_recommender_system

# %%
! git clone https://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@github.com/yongkangzhao/graph_based_recommender_system.git
# Out:
# Cloning into 'graph_based_recommender_system'...
# remote: Enumerating objects: 1277, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 1277 (delta 28), reused 0 (delta 0), pack-reused 1224
# Receiving objects: 100% (1277/1277), 292.94 MiB | 16.65 MiB/s, done.
# Resolving deltas: 100% (607/607), done.
# Checking out files: 100% (341/341), done.

# %%
import os
os.environ['PYTHONPATH'] += ":/content/drive/MyDrive/graph_based_recommender_system/models/kge"

# %%
# %cd /content/drive/MyDrive/graph_based_recommender_system/models/kge
# Out:
# /content/drive/MyDrive/graph_based_recommender_system/models/kge

# %%
! python data/preprocess/preprocess_default.py data/subset_KG/
# Out:
# Preprocessing data/subset_KG/...
# Found 87642 triples in train.txt
# Found 9738 triples in valid.txt
# Found 133 triples in test.txt
# 7 distinct relations
# 41558 distinct entities
# Writing relation and entity map...
# dataset: {files.entity_ids.filename: entity_ids.del, files.entity_ids.type: map, files.relation_ids.filename: relation_ids.del,
#   files.relation_ids.type: map, files.test.filename: test.del, files.test.size: 133,
#   files.test.split_type: test, files.test.type: triples, files.test_without_unseen.filename: test_without_unseen.del,
#   files.test_without_unseen.size: 133, files.test_without_unseen.split_type: test,
#   files.test_without_unseen.type: triples, files.train.filename: train.del, files.train.size: 87642,
#   files.train.split_type: train, files.train.type: triples, files.train_sample.filename: train_sample.del,
#   files.train_sample.size: 9738, files.train_sample.split_type: train, files.train_sample.type: triples,
# ...

# %%
! python data/preprocess/preprocess_default.py data/subset_likes/
# Out:
# Preprocessing data/subset_likes/...
# Found 1068 triples in train.txt
# Found 133 triples in valid.txt
# Found 133 triples in test.txt
# 1 distinct relations
# 945 distinct entities
# Writing relation and entity map...
# dataset: {files.entity_ids.filename: entity_ids.del, files.entity_ids.type: map, files.relation_ids.filename: relation_ids.del,
#   files.relation_ids.type: map, files.test.filename: test.del, files.test.size: 133,
#   files.test.split_type: test, files.test.type: triples, files.test_without_unseen.filename: test_without_unseen.del,
#   files.test_without_unseen.size: 133, files.test_without_unseen.split_type: test,
#   files.test_without_unseen.type: triples, files.train.filename: train.del, files.train.size: 1068,
#   files.train.split_type: train, files.train.type: triples, files.train_sample.filename: train_sample.del,
#   files.train_sample.size: 133, files.train_sample.split_type: train, files.train_sample.type: triples,
# ...

# %% [markdown]
# # **Run Jobs**
#
# - Job yaml files are from ./tune_jobs
# - Job results will be stored at ./results/{job_name}
# - First time running a job:
#     ```! kge start tune_jobs/{job_name}.yaml --folder ./results/{job_name}```
# - Resume a started job, e.g. if colab disconnects, simply run ```! kge resume ./results/{job_name}```
# - Push folder ./results/{job_name} to repo!

# %%
! kge start tune_jobs/subset_KG_transe_bce.yaml --folder ./results/subset_KG_transe_bce
# Out:
# Loading configuration tune_jobs/subset_KG_transe_bce.yaml...
# ...
# Using folder: ./results/subset_KG_transe_bce
# Loading configuration of dataset subset_KG from /content/drive/MyDrive/graph_based_recommender_system/models/kge/data/subset_KG ...
# ...
# Loaded 41558 keys from map entity_ids
# Loaded 7 keys from map relation_ids
# Loaded 87642 train triples
# Loaded 9738 valid triples
# Loaded 133 test triples
# [39e32949] Using device pool: ['cuda']
# [39e32949] Configuration:
# [39e32949]   1vsAll: {class_name: TrainingJob1vsAll}
# [39e32949]   KvsAll:
# [39e32949]     class_name: TrainingJobKvsAll
# [39e32949]     label_smoothing: 0.0
# [39e32949]     query_types: {_po: true, s_o: false, sp_: true}
# [39e32949]   ax_search:
# [39e32949]     class_name: AxSearchJob
# [39e32949]     num_sobol_trials: 10
# [39e32949]     num_trials: 150
# [39e32949]     parameter_constraints: []
# [39e32949]     parameters:
# [39e32949]     - name: train.batch_size
# [39e32949]       type: choice
# ...

# %%
! kge resume ./results/subset_KG_transe_bce
# Out:
# Resuming from configuration ./results/subset_KG_transe_bce/config.yaml...
# Using folder: ./results/subset_KG_transe_bce
# Loading configuration of dataset subset_KG from /content/drive/MyDrive/graph_based_recommender_system/models/kge/data/subset_KG ...
# ...
# Loaded 41558 keys from map entity_ids
# Loaded 7 keys from map relation_ids
# Loaded 87642 train triples
# Loaded 9738 valid triples
# Loaded 133 test triples
# [7b8094d0] Using device pool: ['cuda']
# [7b8094d0] Resuming search from ./results/subset_KG_transe_bce/checkpoint_00001.pt of job 39e32949-b645-4ecc-adb3-6908110a2de2
# [7b8094d0] Loaded checkpoint from ./results/subset_KG_transe_bce/checkpoint_00001.pt...
# Configuration:
#   1vsAll: {class_name: TrainingJob1vsAll}
#   KvsAll:
#     class_name: TrainingJobKvsAll
#     label_smoothing: 0.0
#     query_types: {_po: true, s_o: false, sp_: true}
#   ax_search:
#     class_name: AxSearchJob
#     num_sobol_trials: 10
#     num_trials: 150
#     parameter_constraints: []
# ...

# %%
! kge start tune_jobs/subset_KG_transe_focal.yaml --folder ./results/subset_KG_transe_focal

# %%
! kge start tune_jobs/subset_likes_transe_bce.yaml --folder ./results/subset_likes_transe_bce

# %%
! kge start tune_jobs/subset_likes_transe_focal.yaml --folder ./results/subset_likes_transe_focal
